# %% [markdown]
# # Текущий алгоритм
# * На изображении находим контуры бумаги и маску многоугольника на ней
# * Находим область с объектами - область расположенная справа от контуров бумаги
# * Находим маску каждого предмета в этой области
# * Параллельным переносом каждого объекта убеждаемся, что весь набор объектов (не) поместится в области многоугольника
#     * Здесь в дальнейшем можно добавить возможность вращения объектов -> возрастет сложность алгоритма по их размещению (или можно подумать над другим вариантом)

# %%
# %matplotlib inline
import lib_impl as lib
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# Исходное изображение

# %%
path_to_img = 'D:/signal processing/big_lab/Intelligent-Placer/pictures/input/8.jpg'
img = cv2.cvtColor(cv2.imread(path_to_img), cv2.COLOR_BGR2GRAY)
plt.imshow(img, cmap='gray')

# %% [markdown]
# Найдем маску многоугольника

# %%
paper_contours, polygon_mask = lib.find_paper_contours_and_polygon_mask(path_to_img)
plt.imshow(polygon_mask, cmap='gray')

# %% [markdown]
# Найдем маску каждого предмета на фотографии

# %%
object_masks_with_areas = lib.find_object_masks_with_areas(path_to_img, paper_contours)

# %% [markdown]
# Посмотрим на результат работы алгоритма по размещению объектов в многоугольнике

# %%
lib.can_objects_fit_in_polygon(polygon_mask, object_masks_with_areas)
# Out:
# True

# %% [markdown]
# Точность распознавания = 0.818
